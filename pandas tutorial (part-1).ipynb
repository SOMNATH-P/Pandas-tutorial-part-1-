# %%
#how to install differant modules in jupyternotebook

# %%
pip
# Out:
# Usage:
#   C:\ProgramData\Anaconda3\python.exe -m pip <command> [options]
#
# Commands:
#   install                     Install packages.
#   download                    Download packages.
#   uninstall                   Uninstall packages.
#   freeze                      Output installed packages in requirements format.
#   list                        List installed packages.
#   show                        Show information about installed packages.
#   check                       Verify installed packages have compatible dependencies.
#   config                      Manage local and global configuration.
#   search                      Search PyPI for packages.
#   wheel                       Build wheels from your requirements.
#   hash                        Compute hashes of package archives.
#   completion                  A helper command used for command completion.
#   debug                       Show information useful for debugging.
# ...

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#importing pandas module in jupyter notebook

# %%
import pandas as pd

# %%
#import-> it is a keyword used to install each and every in python
#pandas-> python module(open source library )
#pd->  pandas series object

# %%
#reading excel (.xlsx) dataset using pandas

# %%
df = pd.read_excel("Desktop\\empdata.xlsx")
df
# Out:
#    empid   ename  salary        doj
# 0   1001  ganesh   10000 2020-10-10
# 1   1002    anil   20000 2010-03-20
# 2   1003  gaurav  150000 2002-03-03
# 3   1004    hema   50000 2016-10-09
# 4   1005   laxmi   80000 2010-08-10
# 5   1006   anant   80000 2010-09-09

# %%
#df -> it is a data frame object used to represent rows & colums in each dataset
#read_excel -> this function is used to reading (.xlsx) dataset

# %%
#reading excel (.csv) dataset using pandas

# %%
df = pd.read_csv("Desktop\\netflix.csv")

# %%
df
# Out:
#      show_id     type                                    title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7782   s7783    Movie                                     Zozo
# 7783   s7784    Movie                                   Zubaan
# 7784   s7785    Movie                        Zulu Man in Japan
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
#Reading python dictionary using pandas

# %%
data = {'Name': ['Anjali', 'Rahul' ], 'Age': [7,12], 'Class': ['First', 'Second']}
df =pd.DataFrame (data)
df
# Out:
#      Name  Age   Class
# 0  Anjali    7   First
# 1   Rahul   12  Second

# %%
#Reading python List & Tuples using Pandas

# %%
list = ["apple", "banana", "cherry"]
items=pd.DataFrame (list, columns=["Fruits"])
items
# Out:
#    Fruits
# 0   apple
# 1  banana
# 2  cherry

# %%
print("thank you Coder's....Keep supporting our channel...i have not any experiance but i have try to give my best.")
print("like,share,subscribe.....!\nkeep watching...!\nsome improvement suggestion....!\ncomment me in comment section.")
print("Bye....Have a great day.....see you in next interesting topic...!")
# Out:
# thank you Coder's....Keep supporting our channel...i have not any experiance but i have try to give my best.
# like,share,subscribe.....!
# keep watching...!
# some improvement suggestion....!
# comment me in comment section.
# Bye....Have a great day.....see you in next interesting topic...!
